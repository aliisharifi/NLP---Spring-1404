# %%
import os
from abc import ABC, abstractmethod
import pathlib

from wikipediaapi import Wikipedia, WikipediaPage

# %%
STATE = 'فارس'
DATA_PATH = os.path.join(
    pathlib.Path('../'),
    'fars',
    'data',
)

# %%
os.makedirs(DATA_PATH, exist_ok=True)

# %%
wiki = Wikipedia(user_agent='Mozilla', language='fa')

# %%
page = wiki.page(STATE)

# %%
with open(os.path.join(DATA_PATH, page.title), 'w+',encoding='utf-8') as f:
    f.write(page.text)

# %%
class CrawlingLogic(ABC):

    @abstractmethod
    def do_crawling(self, title: str, page: WikipediaPage) -> bool:
        raise NotImplementedError()

# %%
class PageContainsKeyword(CrawlingLogic):


    def __init__(self, keyword: str):
        super().__init__()
        self.keyword = keyword

    def do_crawling(self, title, page):
        return self.keyword in page.text

# %%
class LinkContainsKeyword(CrawlingLogic):


    def __init__(self, keyword: str):
        super().__init__()
        self.keyword = keyword

    def do_crawling(self, title, page):
        return self.keyword in title

# %%
class CrawlAll(CrawlingLogic):

    def do_crawling(self, title, page):
        return True

# %%
def wiki_crawler(
    page: WikipediaPage,
    base_path: str,
    crawling_logic: CrawlingLogic,
):
    """
        checks all references in the `page` and crawls references containing keyword
    """
    for title, info in page.links.items():
        path = os.path.join(base_path, title)
        if os.path.exists(path):
            print(title, 'already exists')
            continue
        try:
            if crawling_logic.do_crawling(title, info):
                with open(path, 'w+') as f:
                    f.write(info.text)
            else:
                print('irrelevant page:', title)
        except Exception as e:
            print(e)

# %%
wiki_crawler(
    page=page,
    base_path=DATA_PATH,
    crawling_logic=PageContainsKeyword(STATE)
)
# Out:
# Wayback Machine already exists
# آب باریک already exists
# آب پیازک already exists
# آباده already exists
# آباده طشک already exists
# آبرُفتی already exists
# آبشار مارگون already exists
# آبلیمو already exists
# آب‌های زیرزمینی already exists
# آتشکده already exists
# آرامگاه حافظ already exists
# آرامگاه کوروش بزرگ already exists
# آریایی already exists
# آزادراه شیراز-اصفهان already exists
# آزادراه شیراز–بوشهر already exists
# آزادراه لامرد–پارسیان already exists
# آزادراه کنارگذر شمال‌غربی شیراز already exists
# آسیای میانه already exists
# آش already exists
# آش سبزی already exists
# آش کارده already exists
# آشوربنیپال already exists
# آشوریان already exists
# آفات already exists
# آفریقا already exists
# آقا محمد خان قاجار already exists
# آل بویه already exists
# آل مظفر already exists
# آنغوزه already exists
# آهو already exists
# آهک already exists
# آهک (سنگ) already exists
# آینه‌کاری already exists
# ابن بطوطه already exists
# اتابکان فارس already exists
# ادبیات already exists
# ارار already exists
# ارجان already exists
# ارخالق already exists
# ارد (گراش) already exists
# اردشیر بابکان already exists
# اردشیر خوره already exists
# اردشیرخوره already exists
# اردوان پنجم already exists
# اردک already exists
# اردکان (فارس) already exists
# ارسنجان already exists
# اروپا already exists
# ارگ کریمخانی already exists
# ارگ کریم‌خان already exists
# استان آذربایجان شرقی already exists
# استان آذربایجان غربی already exists
# استان اردبیل already exists
# استان اصفهان already exists
# استان البرز already exists
# استان ایلام already exists
# استان بوشهر already exists
# استان تهران already exists
# استان خراسان جنوبی already exists
# استان خراسان رضوی already exists
# استان خراسان شمالی already exists
# استان خوزستان already exists
# استان زنجان already exists
# استان سمنان already exists
# استان سیستان و بلوچستان already exists
# استان قزوین already exists
# استان قم already exists
# استان لرستان already exists
# استان مازندران already exists
# استان مرکزی already exists
# استان هرمزگان already exists
# استان همدان already exists
# استان چهارمحال و بختیاری already exists
# استان کردستان already exists
# استان کرمان already exists
# استان کرمانشاه already exists
# استان کهگیلویه و بویراحمد already exists
# استان گلستان already exists
# استان گیلان already exists
# استان یزد already exists
# استانداری فارس already exists
# استان‌های ایران already exists
# استان‌های ایران بر پایه جمعیت already exists
# استخر already exists
# استخر (شهر) already exists
# استهبان already exists
# استیاکس already exists
# اسکندر مقدونی already exists
# اسکی (ابهام‌زدایی) already exists
# اسیر (شهر) already exists
# اشرف افغان already exists
# اشکانیان already exists
# اشکنان already exists
# اصفهان already exists
# اعراب خمسه already exists
# افاغنه already exists
# افزر already exists
# اقتصاد already exists
# اقلید already exists
# الله‌وردی خان گرجی already exists
# المنطبعه فی الفارس already exists
# الهیات already exists
# الکترونیک already exists
# امام قلی خان already exists
# امام‌شهر already exists
# امپراتوری آشور already exists
# انار already exists
# انجیر already exists
# انجیر وحشی already exists
# انزان already exists
# انشان already exists
# انقلاب اسلامی already exists
# اهل (لامرد) already exists
# اوز already exists
# اکبرآباد (کوار) already exists
# ایالت already exists
# ایج already exists
# ایران already exists
# ایرانیان فارسی‌زبان already exists
# ایران‌خودرو already exists
# ایزدخواست already exists
# ایستگاه راه‌آهن آباده already exists
# ایستگاه راه‌آهن اقلید already exists
# ایستگاه راه‌آهن سعادت‌شهر already exists
# ایستگاه راه‌آهن شیراز already exists
# ایستگاه راه‌آهن صفاشهر already exists
# ایل باصری already exists
# ایل قشقایی already exists
# ایل ممسنی already exists
# ایل نفر already exists
# ایلات ایران already exists
# ایلات خمسه already exists
# ایلام (تمدن) already exists
# ایلامیان already exists
# اینانلو already exists
# بابامنیر already exists
# باباکوهی already exists
# باب‌انار already exists
# بادام سوخته already exists
# بادام کوهی already exists
# باران already exists
# باریت already exists
# بازار جهرم already exists
# بازار قیصریه لار already exists
# بازار وکیل already exists
# بازار کازرون already exists
# باستان‌شناسی already exists
# باشگاه فوتبال فجر شهید سپاسی شیراز already exists
# باشگاه فوتبال قشقایی شیراز already exists
# باصری already exists
# باغ ارم already exists
# باغ اقبال آباد already exists
# باغ ایرانی already exists
# باغ ایرانی پاسارگاد already exists
# باغ ایلخانی (شیراز) already exists
# باغ تکیه هفت‌تنان already exists
# باغ جنت already exists
# باغ جهان‌نما already exists
# باغ دلگشا already exists
# باغ سلطان آباد already exists
# باغ سنقری already exists
# باغ عفیف آباد already exists
# باغ عفیف‌آباد already exists
# باغ نارنجستان قوام already exists
# باغ ناری already exists
# باغ نظر (شیراز) already exists
# باغ نظر (کازرون) already exists
# باغ نوابی already exists
# باغ کچل پادشاه already exists
# باغ گلشن (شیراز) already exists
# بالنگستان already exists
# برازجان already exists
# برج ننه نادر already exists
# برف already exists
# برلین already exists
# برم‌دلک already exists
# برنامه توسعه پنجم already exists
# برنج already exists
# برگه‌دان مستند مجازی بین‌المللی already exists
# بلوط already exists
# بنارویه already exists
# بند امیر already exists
# بند امیر (رود کر) already exists
# بندر خمیر already exists
# بندر لنگه already exists
# بندرعباس already exists
# بنزین already exists
# بنه already exists
# بهار already exists
# بهارلو already exists
# بهارنارنج already exists
# بهداشت already exists
# بهرام فره‌وشی already exists
# بهشت گمشده (مرودشت) already exists
# بهمن (شهر) already exists
# بوانات already exists
# بورس شیراز already exists
# بوریابافی already exists
# بوشهر already exists
# بیابان already exists
# بیرم already exists
# بیشاپور already exists
# بیضا already exists
# بین‌المللی already exists
# بین‌النهرین already exists
# تابستان already exists
# تاتی already exists
# تاریخ علوم already exists
# تاریخ فارس already exists
# تاریخ فارس در دوره قاجاریه already exists
# تاریخ یعقوبی already exists
# تالاب ارژن already exists
# تاورنیه already exists
# تایر already exists
# تحریم تنباکو already exists
# تخت جمشید already exists
# تخت گوهر already exists
# تراورتن already exists
# تراکم جمعیت already exists
# تربیت معلم already exists
# ترشی already exists
# ترکی آذربایجانی already exists
# ترکی قشقایی already exists
# ترک‌زبان already exists
# تغذیه already exists
# تفتان already exists
# تله‌کابین already exists
# تن (یکا) already exists
# تنباکو already exists
# تنگ براق already exists
# تنگ چوگان already exists
# تنگه بلاغی already exists
# تهران already exists
# توانبخشی already exists
# توده هوا already exists
# توربین بادی already exists
# تیسفون already exists
# تیمور already exists
# تیهو already exists
# جاجیم already exists
# جاذبه‌های گردشگری استان فارس بر پایه نوع already exists
# جاذبه‌های گردشگری بر پایه شهرستان در استان فارس already exists
# جام خلیج فارس already exists
# جان کیج already exists
# جزایر خلیج فارس already exists
# جشن هنر شیراز already exists
# جشن‌های ۲۵۰۰ ساله شاهنشاهی ایران already exists
# جمعیت شهرستان‌های استان فارس already exists
# جنت‌شهر already exists
# جنوب already exists
# جنگ جهانی اول already exists
# جهان already exists
# جهرم already exists
# جو (گیاه) already exists
# جویم already exists
# حاجی بادام already exists
# حاجی‌آباد (زرین‌دشت) already exists
# حاجی‌آباد (هرمزگان) already exists
# حافظیه already exists
# حرم شاهچراغ already exists
# حرم شاه‌چراغ already exists
# حسامی already exists
# حسن پیرنیا already exists
# حسن‌آباد (اقلید) already exists
# حسینعلی امیری already exists
# حسینعلی میرزا فرمانفرما already exists
# حصیربافی already exists
# حقوق already exists
# حلوای کاسه already exists
# حلیم بادمجان already exists
# حمام وکیل already exists
# حمام وکیل (شیراز) already exists
# حمله اعراب به پارس already exists
# حمله مغول به سلطنت خوارزمشاه already exists
# حنا already exists
# خاتم already exists
# خاتم سازی already exists
# خاتم کاری already exists
# خاتم‌کاری already exists
# خان زنیان already exists
# خانمین already exists
# خانه زینت‌الملوک already exists
# خانوار already exists
# خاوران (فارس) already exists
# خاک صنعتی already exists
# خاک نسوز already exists
# خراسان already exists
# خراطی already exists
# خرامه already exists
# خرداد already exists
# خرس قهوه‌ای already exists
# خرما already exists
# خرمای شاهانی already exists
# خرمن کوه already exists
# خزنده already exists
# خشت already exists
# خشت (شهر) already exists
# خط دیجیتال مشترک نامتقارن already exists
# خفر already exists
# خلنو already exists
# خنج already exists
# خواجه جمالی (بختگان) already exists
# خودرو already exists
# خودرو برقی already exists
# خودروهای برقی already exists
# خور (فارس) already exists
# خوراک already exists
# خوزستان already exists
# خوزی (مهر) already exists
# خومه‌زار already exists
# خیرآباد (خرامه) already exists
# داراب already exists
# دارابجرد already exists
# دارابگرد already exists
# داروسازی already exists
# دارکوب already exists
# داریان already exists
# دامداری already exists
# دامپزشکی already exists
# دانشنامه بریتانیکا already exists
# دانشکده علوم پزشکی لارستان already exists
# دانشکده علوم پزشکی گراش already exists
# دانشگاه آزاد اسلامی already exists
# دانشگاه جهرم already exists
# دانشگاه سلمان فارسی کازرون already exists
# دانشگاه شیراز already exists
# دانشگاه صنعتی شیراز already exists
# دانشگاه علمی کاربردی already exists
# دانشگاه علوم پزشکی already exists
# دانشگاه علوم پزشکی جهرم already exists
# دانشگاه علوم پزشکی شیراز already exists
# دانشگاه علوم پزشکی فسا already exists
# دانشگاه فسا already exists
# دانشگاه فنی و حرفه‌ای (ایران) already exists
# دانشگاه هنر شیراز already exists
# دانشگاه پیام نور already exists
# دانه‌های روغنی already exists
# دانوب already exists
# دبیران already exists
# درنا already exists
# دریاچه already exists
# دریاچه ارومیه already exists
# دریاچه بختگان already exists
# دریاچه برم شور already exists
# دریاچه طشک already exists
# دریاچه مهارلو already exists
# دریاچه هرم already exists
# دریاچه هفت برم already exists
# دریاچه هیرم already exists
# دریاچه پریشان already exists
# دریاچه کافتر already exists
# دریاچه‌های استان فارس already exists
# دریای سرخ already exists
# دریای مدیترانه already exists
# دسترسی با شماره‌گیری already exists
# دستگاه مختصات جغرافیایی already exists
# دشت ارژن already exists
# دشت برم already exists
# دماوند already exists
# دمپختک already exists
# دنا already exists
# دندان‌پزشکی already exists
# دهرم already exists
# دهکده المپیک شیراز already exists
# دهکویه already exists
# دو پیازه آلو already exists
# دوای آرد و روغن already exists
# دوبرجی already exists
# دوزه already exists
# دوزیستان already exists
# دولت راشدین already exists
# دومیر already exists
# دوچرخه‌سواری already exists
# دژکرد already exists
# ذرت already exists
# رئیس‌جمهور already exists
# رادیو جهرم already exists
# رامجرد already exists
# راهنمای مستند تخت جمشید (کتاب) already exists
# راه‌آهن already exists
# رب پلو already exists
# رحمت‌آباد (زرقان) already exists
# رستاق (داراب) already exists
# رسوب already exists
# رشته کوه زاگرس already exists
# رنگینک already exists
# روان‌شناسی already exists
# رود کر already exists
# رودخانه آغاج already exists
# رودخانه خشک already exists
# رودخانه سیمکان already exists
# رودخانه شادکام already exists
# رودخانه شش پیر already exists
# رودخانه شور جهرم already exists
# رودخانه شور لار already exists
# رودخانه فهیلان already exists
# رودخانه موند already exists
# رودخانه کر already exists
# رودخانه‌های استان فارس already exists
# روزنامه‌نگاری already exists
# روستا already exists
# رونیز already exists
# روی already exists
# ریاضی already exists
# ریال already exists
# ریچارد نلسون فرای already exists
# زالزالک already exists
# زاهدشهر already exists
# زاگرس already exists
# زبان ارمنی already exists
# زبان اچمی already exists
# زبان ترکی قشقایی already exists
# زبان عربی already exists
# زبان فارسی already exists
# زبان فارسی دری already exists
# زبان فارسی میانه already exists
# زبان قشقایی already exists
# زبان لری already exists
# زبان کهمره‌ای already exists
# زبان‌های رایج در ایران already exists
# زردکوه already exists
# زرقان already exists
# زعفران already exists
# زمستان already exists
# زمین‌شناسی already exists
# زندیه already exists
# زنگی‌آباد (مرودشت) already exists
# زیمنس already exists
# سازمان میراث فرهنگی، صنایع دستی و گردشگری already exists
# ساسان already exists
# ساسانیان already exists
# ساعت تابستانی already exists
# ساعت رسمی ایران already exists
# سبزپوشان (کوه) already exists
# سبلان already exists
# سد درودزن already exists
# سد رودبال فارس already exists
# سده (اقلید) already exists
# سراسرنما already exists
# سرامیک already exists
# سرامیک چینی already exists
# سرامیک‌سازی already exists
# سرب already exists
# سرزمین فارس already exists
# سرو already exists
# سروستان already exists
# سعادت آباد already exists
# سعادت‌شهر already exists
# سعدی already exists
# سعدیه already exists
# سفال already exists
# سفالگری already exists
# سفال‌کاری already exists
# سفیداب already exists
# سلجوقیان already exists
# سلطان‌شهر already exists
# سلوکیان already exists
# سماموس already exists
# سمیرم already exists
# سناخریب already exists
# سنجاب already exists
# سند (رود) already exists
# سنگ already exists
# سنگ آهن already exists
# سنگ آهک already exists
# سنگ خارا already exists
# سنگ مرمر already exists
# سنگ نمک already exists
# سنگ گچ already exists
# سن‌بران already exists
# سهند already exists
# سوارکاری already exists
# سودان already exists
# سورمق already exists
# سوغات already exists
# سپیدان already exists
# سیالان already exists
# سیب‌زمینی already exists
# سید جمال الدین اسدآبادی already exists
# سیدان (شهر) already exists
# سیراف already exists
# سیلیس already exists
# سیمان already exists
# سیوند already exists
# سیوندی already exists
# شاردن already exists
# شامی already exists
# شاه اسماعیل صفوی already exists
# شاهان‌کوه already exists
# شاهچراغ already exists
# شاه‌البرز already exists
# شاه‌وار already exists
# شاپورخوره already exists
# شبه جزیره already exists
# شرکت آلومینیوم جنوب already exists
# ششده already exists
# شعر already exists
# شماره استاندارد بین‌المللی پیایند already exists
# شماره استاندارد بین‌المللی کتاب already exists
# شمال already exists
# شمشی-ادد پنجم already exists
# شناساگر اشیاء دیجیتال already exists
# شهر already exists
# شهر شاپور already exists
# شهر گور already exists
# شهرسازی already exists
# شهرستان already exists
# شهرستان آباده already exists
# شهرستان ارسنجان already exists
# شهرستان استهبان already exists
# شهرستان اقلید already exists
# شهرستان اوز already exists
# شهرستان بختگان already exists
# شهرستان بستک already exists
# شهرستان بوانات already exists
# شهرستان بیضا already exists
# شهرستان جهرم already exists
# شهرستان جویم already exists
# شهرستان خرامه already exists
# شهرستان خرم‌بید already exists
# شهرستان خفر already exists
# شهرستان خنج already exists
# شهرستان داراب already exists
# شهرستان رستم already exists
# شهرستان زرقان already exists
# شهرستان زرین‌دشت already exists
# شهرستان سروستان already exists
# شهرستان سرچهان already exists
# شهرستان سپیدان already exists
# شهرستان شیراز already exists
# شهرستان فراشبند already exists
# شهرستان فسا already exists
# شهرستان فیروزآباد already exists
# شهرستان قیر و کارزین already exists
# شهرستان لارستان already exists
# شهرستان لامرد already exists
# شهرستان مرودشت already exists
# شهرستان ممسنی already exists
# شهرستان مهر already exists
# شهرستان نی‌ریز already exists
# شهرستان پاسارگاد already exists
# شهرستان کازرون already exists
# شهرستان کوار already exists
# شهرستان کوه‌چنار already exists
# شهرستان گراش already exists
# شهرپیر already exists
# شهرک صنعتی already exists
# شور دهرم (رود) already exists
# شورای همکاری خلیج فارس already exists
# شوش already exists
# شکر already exists
# شکر پلو already exists
# شکر پنیر already exists
# شیراز already exists
# شیرباد already exists
# شیرکوه (یزد) already exists
# شیرین بیان already exists
# شیشه already exists
# شیشه‌سازی already exists
# شیمی already exists
# صاایران already exists
# صدا و سیمای مرکز فارس already exists
# صدرا (فارس) already exists
# صغاد already exists
# صفاریان already exists
# صفاشهر already exists
# صفویان already exists
# صنایع already exists
# صنایع دستی already exists
# صنایع قطعات الکترونیک ایران already exists
# صنعت already exists
# طایفه already exists
# طراحی already exists
# طسوج (کوار) already exists
# عاشیق already exists
# عبدالحسین زرین‌کوب already exists
# عثمان already exists
# عرب already exists
# عرب خمسه already exists
# عربستان already exists
# عربی already exists
# عربی خمسه already exists
# عرض جغرافیایی already exists
# عرقیات already exists
# عروسی already exists
# عزا already exists
# عشایر already exists
# عضدالدوله دیلمی already exists
# علامرودشت already exists
# علم already exists
# علوم اجتماعی already exists
# علوم انسانی already exists
# علوم تربیتی already exists
# علوم سیاسی already exists
# علوم پایه already exists
# علیرضا شاپور شهبازی already exists
# عمادشهر already exists
# عمارت کلاه‌فرنگی آباده already exists
# عمران already exists
# عمرو لیث already exists
# عیلام already exists
# غار سنگتراشان already exists
# غار سنگ‌تراشان already exists
# غار سیده خاتون already exists
# غار شاپور already exists
# غاز already exists
# غلات already exists
# غلامحسین نوذری already exists
# غیرانتفاعی already exists
# فارسی already exists
# فارسی‌زبان already exists
# فارسی‌زبانان already exists
# فاروق (مرودشت) already exists
# فال (مهر) already exists
# فالوده already exists
# فتحعلی‌شاه already exists
# فتح‌آباد (مرودشت) already exists
# فدامی already exists
# فراشبند already exists
# فرح دیبا already exists
# فرسایش already exists
# فرصت‌الدوله شیرازی already exists
# فرهنگ already exists
# فرهنگ در استان فارس already exists
# فرهنگستان زبان و ادب فارسی already exists
# فرودگاه already exists
# فرودگاه آباده already exists
# فرودگاه بین‌المللی شهدای جهرم already exists
# فرودگاه بین‌المللی شهدای لامرد already exists
# فرودگاه بین‌المللی شیراز already exists
# فرودگاه داراب already exists
# فرودگاه زرقان already exists
# فرودگاه شیراز already exists
# فرودگاه فسا already exists
# فرودگاه لارستان already exists
# فسا already exists
# فلامینگو already exists
# فلز already exists
# فلزکاری already exists
# فهرست استان‌های ایران already exists
# فهرست استان‌های ایران بر پایه شاخص توسعه انسانی already exists
# فهرست استان‌های ایران بر پایه مساحت already exists
# فهرست باغ‌های تاریخی استان فارس already exists
# فهرست بخش‌های استان فارس already exists
# فهرست بلندترین قله استان‌های ایران already exists
# فهرست بیمارستان‌های استان فارس already exists
# فهرست جاذبه‌های گردشگری استان فارس already exists
# فهرست جای‌های دیدنی استان فارس already exists
# فهرست دهستان‌های استان فارس already exists
# فهرست روستاهای بزرگ استان فارس already exists
# فهرست شهرستان‌های استان فارس already exists
# فهرست شهرهای استان فارس already exists
# فهرست شهرهای استان فارس بر پایه مساحت already exists
# فهرست شهرهای ایران بر پایه جمعیت already exists
# فهرست صنایع دستی استان فارس already exists
# فهرست مراکز آموزش عالی استان فارس already exists
# فهرست مراکز استان‌های ایران already exists
# فهرست مطبوعات فارس already exists
# فهرست نمایندگان دوره پنجم مجلس خبرگان رهبری already exists
# فهرست پرجمعیت‌ترین روستاهای استان فارس already exists
# فوتبال already exists
# فوتسال already exists
# فولکلور already exists
# فیبر نوری already exists
# فیروزآباد already exists
# فیزیک already exists
# قائمیه already exists
# قاجار already exists
# قاجاریه already exists
# قادرآباد (فارس) already exists
# قالی already exists
# قدمگاه جهرم already exists
# قرمه به already exists
# قره‌بلاغ (فسا) already exists
# قشقایی already exists
# قطب‌آباد already exists
# قطرویه already exists
# قلعه انگشت گبری already exists
# قلعه اژدهاپیکر already exists
# قلعه دختر (فیروزآباد) already exists
# قلمزنی already exists
# قلم‌زنی already exists
# قله برف‌انبار already exists
# قله کوبری (همدان) already exists
# قنبرپلو already exists
# قند already exists
# قوچ already exists
# قیر (شهر) already exists
# لار already exists
# لارستان already exists
# لامرد already exists
# لبنیات already exists
# لر already exists
# لرها already exists
# لری already exists
# لطفعلی‌خان زند already exists
# لطف‌الله دژکام already exists
# لطیفی already exists
# لهجه جهرمی already exists
# لهجه شیرازی already exists
# لهجه کازرونی already exists
# لپویی already exists
# لیدوما already exists
# لیموزین already exists
# لیگ برتر خلیج فارس already exists
# لیگ دسته اول فوتبال ایران already exists
# مادرسلیمان already exists
# مارن already exists
# مامایی already exists
# ماندانا already exists
# مبارک‌آباد (قیر و کارزین) already exists
# مجلس خبرگان رهبری already exists
# مجموعه ورزشی تختی جهرم already exists
# محمدجعفر ادیب شیرازی already exists
# محمدرضا پهلوی already exists
# محمدشاه قاجار already exists
# محمله already exists
# مخابرات already exists
# مدرس (هند) already exists
# مدیریت already exists
# مردم عرب already exists
# مردم قشقایی already exists
# مردم لارستانی already exists
# مردم لر already exists
# مردم کرد already exists
# مرس کانینگهام already exists
# مرمت already exists
# مرودشت already exists
# مرکبات already exists
# مرکز استان already exists
# مزایجان (بوانات) already exists
# مس already exists
# مساحت already exists
# مسجد نصیرالملک already exists
# مسجد نو شیراز already exists
# مسجد و مدرسه خان already exists
# مسجد وکیل already exists
# مسجد کبیر نی‌ریز already exists
# مسقطی لاری already exists
# مسلمان already exists
# مشکان (نی‌ریز) already exists
# مصیری already exists
# مطبوعات already exists
# مظفری (کوار) already exists
# معارف اسلامی already exists
# معرق‌کاری already exists
# معزآباد جابری already exists
# معماری already exists
# مغول already exists
# ممسنی already exists
# منبت کاری چوب already exists
# منبت‌کاری already exists
# منطقه حفاظت شده بهرام گور already exists
# منطقه حفاظت‌شده هرمود لارستان already exists
# منطقه زمانی already exists
# منطقه ویژه اقتصادی جهرم already exists
# منطقه ویژه اقتصادی شیراز already exists
# منطقه ویژه اقتصادی لامرد already exists
# منطقه ویژه اقتصادی کازرون already exists
# منطقه‌بندی استان‌های ایران already exists
# منگنز already exists
# مهاباد already exists
# مهاجرت already exists
# مهارلو already exists
# مهر (شهر) already exists
# مهندسی already exists
# مهندسی برق already exists
# مهندسی شیمی already exists
# مهندسی صنایع already exists
# مهندسی عمران already exists
# مهندسی فناوری اطلاعات already exists
# مهندسی محیط زیست already exists
# مهندسی مواد already exists
# مهندسی مکانیک already exists
# مهندسی هوافضا already exists
# مهندسی کامپیوتر already exists
# مهیاوه already exists
# موبد already exists
# موزیک‌برینز already exists
# موسیقی already exists
# مونیخ already exists
# مکان‌نگاری already exists
# میان‌جنگل already exists
# میان‌شهر already exists
# میخائیل میخائیلوویچ دیاکونوف already exists
# میرزا اسدالله باسمه‌چی already exists
# میرزا محمد کلانتر فارس already exists
# میرزا محمدصالح شیرازی already exists
# میرزای شیرازی already exists
# میلیون already exists
# میلی‌متر already exists
# میمند already exists
# میمند (فارس) already exists
# میوه‌جات already exists
# نادر شاه already exists
# نادرشاه already exists
# نارنجستان قوام already exists
# ناصرالدین شاه already exists
# نان یوخه already exists
# نفت already exists
# نقره already exists
# نقره‌کاری already exists
# نقش رجب already exists
# نقش رستم already exists
# نقشه ایران در دوره افشاریه already exists
# نماینده ولی فقیه already exists
# نمد already exists
# نمدمالی already exists
# نمک already exists
# نمک آبی already exists
# نوبندگان already exists
# نوجین already exists
# نودان already exists
# نورآباد already exists
# نورآباد (فارس) already exists
# نوشیدنی already exists
# نگارگری already exists
# نیروگاه حافظ already exists
# نیروگاه خورشیدی شیراز already exists
# نیروگاه سیکل ترکیبی جهرم already exists
# نیروگاه سیکل ترکیبی فارس already exists
# نیروگاه سیکل ترکیبی کازرون already exists
# نیروگاه گازی شیراز already exists
# نیکل already exists
# نی‌ریز already exists
# هارطون شماونیای شیرازی already exists
# هتل already exists
# هجری قمری already exists
# هخامنش already exists
# هخامنشی already exists
# هرم و کاریان already exists
# هرمزگان already exists
# هلاکوخان already exists
# هماشهر (سپیدان) already exists
# هنر already exists
# هنرهای تجسمی already exists
# هنرهای نمایشی already exists
# هنرهای کاربردی already exists
# هوبره already exists
# هکتار already exists
# هگمتانه already exists
# والاشهر already exists
# وای‌مکس already exists
# وراوی (فارس) already exists
# ورزشگاه حافظیه already exists
# ورزشگاه شهدای ارتش شیراز already exists
# ورزشگاه پارس already exists
# پارت already exists
# پارس already exists
# پارسوآش already exists
# پارسوا already exists
# پارسیان (هرمزگان) already exists
# پارچه already exists
# پارک ملی بختگان already exists
# پارک ملی بمو already exists
# پارک ملی قطرویه already exists
# پاسارگاد already exists
# پاسارگادیان already exists
# پاسخن already exists
# پالایشگاه already exists
# پالایشگاه گاز پارسیان already exists
# پاچه پلو already exists
# پاییز already exists
# پتروشیمی already exists
# پتروشیمی جهرم already exists
# پتروشیمی شیراز already exists
# پتروشیمی کازرون already exists
# پراو already exists
# پردیس already exists
# پرستاری already exists
# پرسپولیس already exists
# پرنده already exists
# پزشکی already exists
# پستاندار already exists
# پلاک خودرو already exists
# پلنگ already exists
# پلیکان already exists
# پنبه already exists
# پوشاک already exists
# پژو پارس already exists
# پیاز already exists
# پیرآب (رود) already exists
# پیراپزشکی already exists
# پیست اسکی تربیت‌بدنی فارس already exists
# پیست اسکی پولادکف already exists
# پیش‌شماره تلفن already exists
# پیکره شاپور یکم already exists
# چاه‌ورز already exists
# چرم already exists
# چغندر قند already exists
# چغندرقند already exists
# چقه already exists
# چهارمحال و بختیاری already exists
# چوب already exists
# چوبخله (رود) already exists
# چیش‌پیش already exists
# کاخ اردشیر بابکان already exists
# کاخ ساسانی سروستان already exists
# کارخانجات مخابرات راه دور already exists
# کارزین already exists
# کازرون already exists
# کاشی already exists
# کاشی معرق already exists
# کاشی هفت رنگ already exists
# کاشی هفت‌رنگ already exists
# کاغذ اخبار already exists
# کامفیروز already exists
# کامپیوتر already exists
# کامیونت already exists
# کان صیفی already exists
# کبک (پرنده) already exists
# کتیرا already exists
# کردهای فارس already exists
# کردی already exists
# کره‌ای (سرچهان) already exists
# کرومیت already exists
# کریم خان زند already exists
# کریمخان زند already exists
# کشاورزی already exists
# کعبه زرتشت already exists
# کفتار already exists
# کلاب کارت already exists
# کلسیم کربنات already exists
# کلم پلو already exists
# کلوچه مسقطی already exists
# کلوچه و مسقطی already exists
# کمبوجیه یکم already exists
# کمپانی هند شرقی already exists
# کنارتخته already exists
# کهگیلویه و بویراحمد already exists
# کوار already exists
# کوارتزیت already exists
# کوره (اوز) already exists
# کوره اردشیر already exists
# کوروش بزرگ already exists
# کوفته سبزی already exists
# کوفته هلو already exists
# کولی کش already exists
# کوه already exists
# کوه اورین already exists
# کوه برم فیروز already exists
# کوه بل already exists
# کوه بلقیس already exists
# کوه بمو already exists
# کوه بیرمی already exists
# کوه تشگر already exists
# کوه تودج already exists
# کوه ختابان already exists
# کوه زلیخا already exists
# کوه سفیدار already exists
# کوه شاه‌جهان already exists
# کوه قلات already exists
# کوه قند یله already exists
# کوه نایبند already exists
# کوه هزار already exists
# کوه کینو already exists
# کوه گر already exists
# کوهمره already exists
# کوهمره جروق already exists
# کوهمره سرخی already exists
# کوهنجان already exists
# کوه‌های استان فارس already exists
# کوپن (رستم) already exists
# کوچ already exists
# کوچ نشینی already exists
# کویر already exists
# کیسه حمام already exists
# کیش already exists
# کیلو وات already exists
# گاز already exists
# گاه‌شماری ایران already exists
# گاه‌شماری میلادی already exists
# گاوکشان already exists
# گبه already exists
# گراز already exists
# گراش already exists
# گربه وحشی already exists
# گردشگاه میان‌کتل شیراز already exists
# گرگ already exists
# گزنفون already exists
# گل گاوزبان already exists
# گلابی وحشی already exists
# گله‌دار already exists
# گلیم already exists
# گل‌گهر already exists
# گندم already exists
# گوجه فرنگی already exists
# گور (شهر باستانی) already exists
# گورخر ایرانی already exists
# گوزن already exists
# گوشت already exists
# گون already exists
# گویش اردکانی already exists
# گویش باصری already exists
# گویش دوانی already exists
# گویش شمال فارس already exists
# گویش عبدویی already exists
# گویش کرشی already exists
# گویش کرونی already exists
# گویش‌های استان فارس already exists
# گچ‌بری already exists
# گیلک already exists
# گیوه‌بافی already exists
# یخنی عدس کلم already exists
# یخنی نخود already exists
# یزد already exists
# یعقوب لیث already exists
# یعقوبی already exists
# یوتی‌سی +۰۳:۳۰ already exists
# یوتی‌سی +۰۴:۳۰ already exists
# یورو already exists
# یونان already exists
# یونان باستان already exists
# ۱۲ اکتبر already exists
# ۱۳۵۰ (خورشیدی) already exists
# ۱۶ اکتبر already exists
# ۱۹۷۱ (میلادی) already exists
# ۲۰ مهر already exists
# ۲۴ مهر already exists
# irrelevant page: ویکی‌پدیا:فهرست یادمان‌های ملی ایران/فارس
# irrelevant page: ویکی‌پدیا:فهرست یادمان‌های ملی ایران/فارس دو
# irrelevant page: ویکی‌پدیا:فهرست یادمان‌های ملی ایران/فارس سه
# ویکی‌پدیا:پروژه‌های خواهر ویکی‌مدیا already exists
# ویکی‌پدیا:پیوندهای مرده already exists
# الگو:استان فارس already exists
# الگو:استان‌های ایران already exists
# الگو:بلندترین قله استان‌های ایران already exists
# بحث الگو:استان فارس already exists
# بحث الگو:استان‌های ایران already exists
# بحث الگو:بلندترین قله استان‌های ایران already exists
# راهنما:داده‌های کتابخانه‌ای already exists
# رده:استان فارس already exists
# رده:مقاله‌های ویکی‌پدیا همراه شناسه‌های GND already exists
# رده:مقاله‌های ویکی‌پدیا همراه شناسه‌های MusicBrainz area already exists
# رده:مقاله‌های ویکی‌پدیا همراه شناسه‌های VIAF already exists
