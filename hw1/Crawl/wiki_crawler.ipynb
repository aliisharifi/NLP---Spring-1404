# %%
import os
from abc import ABC, abstractmethod
import pathlib

from wikipediaapi import Wikipedia, WikipediaPage

# %%
STATE = 'چهارمحال و بختیاری'
DATA_PATH = os.path.join(
    pathlib.Path('../'),
    'chaharmahal-o-bakhtiari',
    'data',
)

# %%
os.makedirs(DATA_PATH, exist_ok=True)

# %%
wiki = Wikipedia(user_agent='Mozilla', language='fa')

# %%
page = wiki.page(STATE)

# %%
with open(os.path.join(DATA_PATH, page.title), 'w+') as f:
    f.write(page.text)

# %%
class CrawlingLogic(ABC):

    @abstractmethod
    def do_crawling(self, title: str, page: WikipediaPage) -> bool:
        raise NotImplementedError()

# %%
class PageContainsKeyword(CrawlingLogic):


    def __init__(self, keyword: str):
        super().__init__()
        self.keyword = keyword

    def do_crawling(self, title, page):
        return self.keyword in page.text

# %%
class LinkContainsKeyword(CrawlingLogic):


    def __init__(self, keyword: str):
        super().__init__()
        self.keyword = keyword

    def do_crawling(self, title, page):
        return self.keyword in title

# %%
class CrawlAll(CrawlingLogic):

    def do_crawling(self, title, page):
        return True

# %%
def wiki_crawler(
    page: WikipediaPage,
    base_path: str,
    crawling_logic: CrawlingLogic,
):
    """
        checks all references in the `page` and crawls references containing keyword
    """
    for title, info in page.links.items():
        path = os.path.join(base_path, title)
        if os.path.exists(path):
            print(title, 'already exists')
            continue
        try:
            if crawling_logic.do_crawling(title, info):
                with open(path, 'w+') as f:
                    f.write(info.text)
            else:
                print('irrelevant page:', title)
        except Exception as e:
            print(e)

# %%
wiki_crawler(
    page=page,
    base_path=DATA_PATH,
    crawling_logic=PageContainsKeyword(STATE)
)
# Out:
# irrelevant page: اتاق آئینه شهرکرد
# irrelevant page: ارمنیان
# irrelevant page: استان آذربایجان شرقی
# irrelevant page: استان آذربایجان غربی
# irrelevant page: استان اردبیل
# irrelevant page: استان البرز
# irrelevant page: استان ایلام
# irrelevant page: استان تهران
# irrelevant page: استان خراسان جنوبی
# irrelevant page: استان خراسان رضوی
# irrelevant page: استان خراسان شمالی
# irrelevant page: استان زنجان
# irrelevant page: استان سمنان
# irrelevant page: استان سیستان و بلوچستان
# irrelevant page: استان فارس
# irrelevant page: استان قزوین
# irrelevant page: استان قم
# irrelevant page: استان مازندران
# irrelevant page: استان مرکزی
# irrelevant page: استان هرمزگان
# irrelevant page: استان همدان
# irrelevant page: استان کردستان
# irrelevant page: استان کرمانشاه
# irrelevant page: استان گلستان
# irrelevant page: استان گیلان
# irrelevant page: استان‌های ایران
# irrelevant page: استبداد صغیر
# irrelevant page: اطلس زبان‌های ایران
# irrelevant page: امامزاده سیدمحمد بارده
# irrelevant page: امامزادگان حلیمه و حکیمه خاتون
# irrelevant page: امیدآباد (فارسان)
# irrelevant page: ایران
# irrelevant page: ایرانیان فارسی‌زبان
# irrelevant page: بخش (تقسیمات کشوری)
# irrelevant page: بخش رودشت
# irrelevant page: بلوط
# irrelevant page: بویراحمدی
# irrelevant page: تاریخ بختیاری (کتاب)
# irrelevant page: تالاب چغاخور
# irrelevant page: ترک‌زبان
# irrelevant page: تفتان
# irrelevant page: تپه سراب (گنبدک)
# irrelevant page: خلنو
# irrelevant page: دانشنامه ایرانیکا
# irrelevant page: دانشنامه بریتانیکا
# irrelevant page: دانشنامه جهان اسلام
# irrelevant page: دز
# irrelevant page: دستگاه مختصات جغرافیایی
# irrelevant page: دماوند
# irrelevant page: دهستان
# irrelevant page: دودمان پهلوی
# irrelevant page: دوره افشاریه
# irrelevant page: دومیر
# irrelevant page: دیمه
# irrelevant page: رانش زمین
# irrelevant page: رودگردی
# irrelevant page: ریزش بهمن
# irrelevant page: زبان‌های اوغوز
# irrelevant page: زلزله
# irrelevant page: سبلان
# irrelevant page: سماموس
# irrelevant page: سندگان
# irrelevant page: سن‌بران
# irrelevant page: سهند
# irrelevant page: سیالان
# irrelevant page: سیل
# irrelevant page: شاهان‌کوه
# irrelevant page: شاه‌البرز
# irrelevant page: شاه‌وار
# irrelevant page: شماره استاندارد بین‌المللی کتاب
# irrelevant page: شهر
# irrelevant page: شهرستان
# irrelevant page: شهرستان ممسنی
# irrelevant page: شهرستان‌های ایران
# irrelevant page: شولستان
# irrelevant page: شیرباد
# irrelevant page: شیرکوه (یزد)
# irrelevant page: صفویان
# irrelevant page: طهران
# irrelevant page: عراق
# irrelevant page: فارسی پهلوی
# irrelevant page: فهرست استان‌های ایران
# irrelevant page: فهرست استان‌های ایران بر پایه شاخص توسعه انسانی
# irrelevant page: فهرست بلندترین قله استان‌های ایران
# irrelevant page: فهرست جاذبه‌های گردشگری استان چهارمحال و بختیاری
# irrelevant page: فهرست مراکز استان‌های ایران
# irrelevant page: فهرست نمایندگان دوره پنجم مجلس خبرگان رهبری
# irrelevant page: قلعه سورک
# irrelevant page: قله برف‌انبار
# irrelevant page: قله کوبری (همدان)
# irrelevant page: لر کوچک
# irrelevant page: لرستان فیلی
# irrelevant page: مجلس خبرگان رهبری
# irrelevant page: محمدعلی شاه قاجار
# irrelevant page: مخاطرات طبیعی
# irrelevant page: مسجد جامع شهرکرد
# irrelevant page: مسعود میرزا ظل السلطان
# irrelevant page: مشروطیت
# irrelevant page: منطقه مسکونی
# irrelevant page: ناوانتم پیلای
# irrelevant page: نماینده ولی فقیه
# irrelevant page: پادشاه
# irrelevant page: پاریس
# irrelevant page: پایتخت
# irrelevant page: پراو
# irrelevant page: پشتکوه (منطقه)
# irrelevant page: پولکی
# irrelevant page: پیست اسکی باباحیدر
# irrelevant page: پیست اسکی بارده
# irrelevant page: پیشکوه
# irrelevant page: چشمه سردآب
# irrelevant page: کان صیفی
# irrelevant page: کایاک
# irrelevant page: کوه اورین
# irrelevant page: کوه بل
# irrelevant page: کوه بلقیس
# irrelevant page: کوه بیرمی
# irrelevant page: کوه تشگر
# irrelevant page: کوه زلیخا
# irrelevant page: کوه شاه‌جهان
# irrelevant page: کوه نایبند
# irrelevant page: کوه هزار
# irrelevant page: گاوکشان
# irrelevant page: گرهارد دورفر
# irrelevant page: ویکی‌پدیا:فهرست یادمان‌های ملی ایران/چهارمحال و بختیاری
# irrelevant page: ویکی‌پدیا:نیازمند منبع
# irrelevant page: ویکی‌پدیا:پیوندهای مرده
# irrelevant page: الگو:Cite book
# irrelevant page: الگو:Cite web
# irrelevant page: الگو:استان چهارمحال و بختیاری
# irrelevant page: الگو:استان‌های ایران
# irrelevant page: الگو:بلندترین قله استان‌های ایران
# irrelevant page: بحث الگو:استان چهارمحال و بختیاری
# irrelevant page: بحث الگو:استان‌های ایران
# irrelevant page: بحث الگو:بلندترین قله استان‌های ایران
# irrelevant page: راهنما:CS1 errors
# irrelevant page: راهنما:خطاهای الگوی یادکرد
# irrelevant page: رده:نگهداری یادکرد:ربات:وضعیت نامعلوم پیوند اصلی
