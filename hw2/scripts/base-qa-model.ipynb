# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %%capture
# !pip install hazm transformers torch nltk -q

# %%
import json
import logging
import re
import string
from collections import defaultdict

from transformers import pipeline
from nltk.tokenize import word_tokenize
import nltk
from hazm import Normalizer, Lemmatizer, word_tokenize

nltk.download('punkt')

logging.basicConfig(
    filename='/kaggle/working/qa_errors.log',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    encoding='utf-8'
)

# Stopwords فارسی
PERSIAN_STOPWORDS = set([
    'آیا', 'ای', 'اما', 'اگر', 'از', 'اش', 'افراد', 'است', 'اسلامی', 'اشاره', 'اصلاً',
    'اعلام', 'افزود', 'اکنون', 'البته', 'اند', 'ان', 'انجام', 'آن', 'آنان', 'آنه', 'آنها',
    'او', 'اول', 'ایم', 'اینجا', 'اینان', 'این', 'اینه', 'اینها', 'باشد', 'بار', 'باره',
    'باید', 'بالا', 'بالای', 'بر', 'برا', 'برای', 'برخی', 'برداری', 'برخوردار', 'بروز',
    'بزرگ', 'بس', 'بسیار', 'بطور', 'بعد', 'بعدا', 'بلافاصله', 'بلکه', 'بله', 'بنابراین',
    'بنده', 'به', 'بها', 'بود', 'بوده', 'بودند', 'بیرون', 'بی', 'بین', 'بیش', 'بیشتر', 'تا',
    'تمام', 'تحت', 'تر', 'تر از', 'ترک', 'تعداد', 'توسط', 'توی', 'تمامی', 'تنها', 'تو',
    'تواند', 'تومان', 'ثبت', 'ثانیاً', 'جاری', 'جدا', 'جز', 'جلوگیری', 'جمعی', 'چرا',
    'چه', 'چیز', 'چند', 'چنین', 'حتی', 'حد', 'حداکثر', 'حدود', 'حق', 'حضرت', 'حتماً',
    'حاضر', 'خود', 'خویش', 'خواه', 'خواهند', 'خوب', 'خودش', 'خیلی', 'دارای', 'داشت',
    'داشته', 'داشتند', 'در', 'درباره', 'درحال', 'درست', 'درصورتی', 'درعین', 'دریافت',
    'دسته', 'دگر', 'دهد', 'دهند', 'دو', 'دوم', 'دوباره', 'دیر', 'دیگر', 'دیگران', 'را',
    'راه', 'راجع', 'رسماً', 'رسید', 'رشد', 'روی', 'زود', 'زیاد', 'زیر', 'سابق', 'سراسر',
    'سری', 'سریعا', 'سریعتاً', 'سعی', 'سوم', 'شد', 'شده', 'شدند', 'شش', 'شما', 'شان',
    'شو', 'شود', 'شوند', 'صفر', 'صرفاً', 'صورت', 'ضد', 'ضمن', 'طبیعی', 'طور', 'طی',
    'ظرف', 'عالی', 'عبارتند', 'عدم', 'عقب', 'علت', 'علیه', 'عنوان', 'غیر', 'فبها', 'فر',
    'فقط', 'فعلاً', 'فوق', 'قابل', 'قبل', 'قبلاً', 'قدر', 'قصد', 'قطعاً', 'قرار', 'قریب',
    'گذشته', 'گذاشتن', 'گر', 'گرفت', 'گرفته', 'گروهی', 'گه', 'گاهی', 'گو', 'گفت', 'گفتند',
    'لذا', 'لطفاً', 'ما', 'مانند', 'مابقی', 'مبتنی', 'متاسفانه', 'مجدد', 'مجدداً', 'محسوب',
    'مختلف', 'مدام', 'مدتی', 'مراجعه', 'مرتب', 'مردم', 'موجب', 'مگر', 'من', 'منتهی',
    'مورد', 'میزان', 'میلیون', 'می', 'نماید', 'نمایند', 'نمی', 'ناشی', 'نخست', 'نخستین',
    'نه', 'نوعی', 'نیاز', 'نزدیک', 'نسبت', 'نشان', 'نشده', 'نظر', 'نفر', 'نقش', 'نیز',
    'نیست', 'نمی‌تواند', 'ها', 'های', 'هایش', 'هر', 'هرگز', 'هزار', 'هست', 'هستند',
    'هم', 'همان', 'همچنان', 'همچنین', 'همه', 'همواره', 'هیچ', 'و', 'وجود', 'ولی', 'وی',
    'پارسال', 'پایین', 'پایین‌تر', 'پشت', 'پس', 'پیش', 'پیشتر', 'چطور', 'چندین', 'کار',
    'کامل', 'کاملاً', 'کجا', 'کرد', 'کرده', 'کردند', 'کس', 'کسانی', 'کل', 'کلیه', 'کم',
    'کماکان', 'کنار', 'کند', 'کنند', 'که', 'کو', 'کی', 'گذشته', 'گذاشته', 'گیر', 'یک'
])

normalizer = Normalizer()
lemmatizer = Lemmatizer()

def normalize_text(text):
    if not text:
        return ""
    text = normalizer.normalize(text.lower().strip())
    text = re.sub(f'[{string.punctuation}]', ' ', text)
    text = re.sub(r'\b\d+\b', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    tokens = word_tokenize(text)
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in PERSIAN_STOPWORDS]
    return ' '.join(tokens)

def is_meaningful_answer(answer, question):
    if not answer or len(answer.strip()) < 20:
        return False
    if re.match(r'^\d+$', answer.strip()) or re.match(r'ص\s*\d+', answer.strip()):
        return False
    if len(answer.strip().split()) < 5:
        return False
    if answer.strip() in question:
        return False
    question_tokens = set(normalize_text(question).split())
    answer_tokens = set(normalize_text(answer).split())
    if not (question_tokens & answer_tokens):
        return False
    return True

def compute_answer_similarity(answer1, answer2):
    tokens1 = set(normalize_text(answer1).split())
    tokens2 = set(normalize_text(answer2).split())
    if not tokens1 or not tokens2:
        return 0.0
    return len(tokens1 & tokens2) / len(tokens1 | tokens2)

def remove_similar_answers(candidates, threshold=0.5):
    unique_candidates = []
    seen = set()
    for cand in sorted(candidates, key=lambda x: x['score'], reverse=True):
        norm_ans = normalize_text(cand['answer'])
        if not norm_ans:
            continue
        if any(compute_answer_similarity(norm_ans, sa) > threshold for sa in seen):
            continue
        seen.add(norm_ans)
        unique_candidates.append(cand)
    return unique_candidates[:3]

def select_relevant_contexts(question, contexts, top_n=3):
    question_tokens = set(normalize_text(question).split())
    scores = []
    for ctx in contexts:
        ctx_text = normalize_text(ctx['context'])
        ctx_tokens = set(ctx_text.split())
        score = len(question_tokens & ctx_tokens) / len(question_tokens | ctx_tokens)
        for keyword in question_tokens:
            if keyword in ctx_text:
                score += 0.1
        scores.append((ctx, score))
    return [ctx for ctx, _ in sorted(scores, key=lambda x: x[1], reverse=True)[:top_n]]
# Out:
# 2025-08-02 07:18:56.631002: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754119137.001260      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754119137.114524      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def process_questions():
    try:
        with open('/kaggle/input/newtestd/Test_data.json', 'r', encoding='utf-8') as f:
            test_data = json.load(f)
        with open('/kaggle/input/aggregate-and-test/aggregate.json', 'r', encoding='utf-8') as f:
            contexts = json.load(f)

        qa_pipeline = pipeline(
            'question-answering',
            model='cis-lmu/glot500-base',
            tokenizer='cis-lmu/glot500-base',
            framework='pt',
            max_answer_len=100,
            min_answer_len=5,
            top_k=10,
            handle_impossible_answer=True
        )

        results = []
        for q in test_data:
            q_id = q['id']
            question = q['question']
            relevant = select_relevant_contexts(question, contexts)
            if not relevant:
                results.append({'id': q_id, 'question': question, 'top_answers': []})
                continue
            candidates = []
            for ctx in relevant:
                try:
                    answers = qa_pipeline(question=question, context=ctx['context'])
                    if not isinstance(answers, list):
                        answers = [answers]
                    for ans in answers:
                        if is_meaningful_answer(ans['answer'], question):
                            candidates.append({
                                'answer': ans['answer'].strip(),
                                'score': ans['score'],
                                'context': ctx['context']
                            })
                except Exception as e:
                    logging.error(f"Error: {str(e)}")
            unique = remove_similar_answers(candidates)
            results.append({'id': q_id, 'question': question, 'top_answers': unique})

        with open('/kaggle/working/qa_results.json', 'w', encoding='utf-8') as f:
            json.dump(results, f, ensure_ascii=False, indent=2)

    except Exception as e:
        logging.error(f"Error in process_questions: {str(e)}")
        raise

if __name__ == "__main__":
    process_questions()
# Out:
# config.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.58G [00:00<?, ?B/s]
# Some weights of XLMRobertaForQuestionAnswering were not initialized from the model checkpoint at cis-lmu/glot500-base and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/496 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/7.66M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/279 [00:00<?, ?B/s]
# Device set to use cuda:0
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
import json

with open('/kaggle/working/qa_results.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "id": 1,
#         "question": "به موجب  پیمان سنت پترزبورگ چه قسمت هایی از ایران به روسیه واگذار شدند؟",
#         "top_answers": [
#             {
#                 "answer": "شد. این پیمان به موجب آن ایران مجبور شد سرزمین‌های وسیعی در قفقاز شمالی، قفقاز جنوبی و آذربایجان شامل دربند (داغستان)، بادکوبه و اراضی تابع",
#                 "score": 2.4586455765529536e-05,
#                 "context": "پیمان سنت پترزبورگ در تاریخ ۲۳ سپتامبر ۱۷۲۳ (۱۲ سپتامبر به تقویم ژولینی) بین ایران و روسیه امضا شد. این پیمان به موجب آن ایران مجبور شد سرزمین‌های وسیعی در قفقاز شمالی، قفقاز جنوبی و آذربایجان شامل دربند (داغستان)، بادکوبه و اراضی تابع اطراف آنها را به روسیه واگذار کند. همچنین تمام نواحی شمال ایران شامل استان‌های گیلان، مازندران و استرآباد نیز تحت این پیمان به روسیه تعلق گرفت. این قرارداد پس از حمله پتر یکم به ایران و به منظور تثبیت اوضاع داخلی امضا شد. طبق این پیمان، سربازان روسی به شاه تهماسب دوم کمک کردند تا آرامش و صلح داخلی را برقرار کند. اهمیت تاریخی این پیمان در آن است که به عنوان یکی از مهم‌ترین توافقات بین روسیه و ایران شناخته می‌شود. این معاهده نه تنها سرزمین‌های وسیعی را به قلمرو روسیه افزود، بلکه تأثیر عمیقی بر ساختار سیاسی و اجتماعی ایران داشت و زمینه‌ساز تغییرات گسترده‌ای در منطقه شد."
پنج ماه تمامی نواحی متصرفی خود را در ایران تخلیه کند. طرفین درگیر این قرارداد ایران و امپراتوری روسیه بودند. نتیجه امضای عهدنامه، تخلیه نیروهای روس از گیلان بود و تأثیرات آن شامل آزادی تجارت بین ایران و روسیه، ایجاد نمایندگی سیاسی در کشورهای دیگر و بازگرداندن شهرهایی مانند بندر، گنجه و دیگر مناطق به ایران بود. اهمیت تاریخی عهدنامه رشت در پایان اشغالگری روسیه در منطقه و بازگشت کنترل این مناطق به ایران نهفته است."
#             }
#         ]
#     },
#     {
#         "id": 3,
#         "question": "چند پیمان که در راستای حفط محیط زیست بودند را نام ببر؟",
#         "top_answers": [
#             {
#                 "answer": "آزمایش‌های هسته‌ای در هوا و آب است که موجب ورود ذرات پرتوزا به محیط زیست و تهدید سلامت عمومی می‌شد. این پیمان که با نام‌های \"پیمان ممنوعیت آزمایش محدود\" و \"پیمان منع آزمایش هسته‌ای\" نیز شناخته می‌شود، توسط کشورهای شوروی،",
#                 "score": 4.2172065150225535e-05,
#                 "context": "پیمان منع آزمایش هسته‌ای که در سال ۱۹۶۳ در شهر مسکو به امضا رسید، به کشورها اجازه می‌دهد تا آزمایش‌های هسته‌ای خود را تنها در زیر زمین انجام دهند. هدف اصلی این پیمان جلوگیری از آزمایش‌های هسته‌ای در هوا و آب است که موجب ورود ذرات پرتوزا به محیط زیست و تهدید سلامت عمومی می‌شد. این پیمان که با نام‌های \"پیمان ممنوعیت آزمایش محدود\" و \"پیمان منع آزمایش هسته‌ای\" نیز شناخته می‌شود، توسط کشورهای شوروی، بریتانیا و آمریکا به امضا رسید. این توافق به کاهش انتشار مواد پرتوزا در جو کمک کرده و روند گسترش سلاح‌های هسته‌ای را کند کرده است. اهمیت تاریخی این پیمان در نگرانی جهانی نسبت به اثرات زیست‌محیطی و امنیتی آزمایش‌های هسته‌ای است."
#             }
#         ]
#     },
#     {
#         "id": 4,
#         "question": "کنوانسیون ورشو چیست؟",
#         "top_answers": [
#             {
#                 "answer": "در سال ۱۹۲۹ در شهر ورشو به امضا رسید و تا سال ۲۰۱۵ توسط ۱۵۲ کشور تصویب شده است. این معاهده شامل پنج فصل بوده و پروتکل الحاقی",
#                 "score": 6.89778826199472e-05,
#                 "context": "کنوانسیون ورشو یک معاهده بین‌المللی است که مسئولیت حمل و نقل افراد، توشه یا کالاها از طریق هواپیما را تنظیم می‌کند. این کنوانسیون در سال ۱۹۲۹ در شهر ورشو به امضا رسید و تا سال ۲۰۱۵ توسط ۱۵۲ کشور تصویب شده است. این معاهده شامل پنج فصل بوده و پروتکل الحاقی آن نیز توسط ۱۳۷ کشور تصویب شده است. هدف اصلی این کنوانسیون، تعیین چارچوب قانونی برای مسئولیت‌های حمل و نقل هوایی بین‌المللی است. اهمیت تاریخی این قرارداد به دلیل تنظیم مسئولیت بین‌المللی در زمینه حمل و نقل هوایی است."
#             },
#             {
#                 "answer": "هدف اصلی این کنوانسیون، تعیین چارچوب قانونی برای مسئولیت‌های حمل و نقل هوایی بین‌المللی است. اهمیت تاریخی این قرارداد به دلیل تنظیم",
#                 "score": 6.886573100928217e-05,
#                 "context": "کنوانسیون ورشو یک معاهده بین‌المللی است که مسئولیت حمل و نقل افراد، توشه یا کالاها از طریق هواپیما را تنظیم می‌کند. این کنوانسیون در سال ۱۹۲۹ در شهر ورشو به امضا رسید و تا سال ۲۰۱۵ توسط ۱۵۲ کشور تصویب شده است. این معاهده شامل پنج فصل بوده و پروتکل الحاقی آن نیز توسط ۱۳۷ کشور تصویب شده است. هدف اصلی این کنوانسیون، تعیین چارچوب قانونی برای مسئولیت‌های حمل و نقل هوایی بین‌المللی است. اهمیت تاریخی این قرارداد به دلیل تنظیم مسئولیت بین‌المللی در زمینه حمل و نقل هوایی است."
#             }
#         ]
#     },
#     {
#         "id": 5,
#         "question": "به موجب پیمان آماسیه چه مناطقی به صفویان و چه مناطقی به عثمانی واگذار شد؟",
#         "top_answers": [
#             {
#                 "answer": "رسید. این پیمان‌نامه در شهر آماسیه واقع در آسیای صغیر به منظور پایان دادن به جنگ‌های بیست‌ساله میان دو قدرت منطقه‌ای آن زمان، ایران صفوی و عثمانی، منعقد شد. بر اساس مفاد این پیمان، ایالت‌های آذربایجان،",
#                 "score": 2.6619029085850343e-05,
#                 "context": "پیمان آماسیه در سال ۱۵۵۵ میلادی میان شاه تهماسب اول از دودمان صفوی و سلطان سلیمان اول از امپراتوری عثمانی به امضا رسید. این پیمان‌نامه در شهر آماسیه واقع در آسیای صغیر به منظور پایان دادن به جنگ‌های بیست‌ساله میان دو قدرت منطقه‌ای آن زمان، ایران صفوی و عثمانی، منعقد شد. بر اساس مفاد این پیمان، ایالت‌های آذربایجان، ارمنستان، داغستان جنوبی و گرجستان شرقی در اختیار دولت صفوی باقی ماندند، در حالی که گرجستان غربی و مناطق عراق کنونی به عثمانی واگذار شدند. این قرارداد حدود ۲۰ سال آرامش و ثبات را بین دو کشور برقرار کرد. شاه تهماسب اول تا پایان عمر خود به مفاد این پیمان پایبند ماند. پیمان آماسیه نخستین معاهده رسمی صلح میان صفویان و عثمانیان به شمار می‌رود و از نظر تاریخی یکی از مهم‌ترین توافقات سیاسی-نظامی در روابط ایران و عثمانی به حساب می‌آید."
#             },
#             {
#                 "answer": "رسید. این پیمان‌نامه در شهر آماسیه واقع در آسیای",
#                 "score": 2.660195968928747e-05,
#                 "context": "پیمان آماسیه در سال ۱۵۵۵ میلادی میان شاه تهماسب اول از دودمان صفوی و سلطان سلیمان اول از امپراتوری عثمانی به امضا رسید. این پیمان‌نامه در شهر آماسیه واقع در آسیای صغیر به منظور پایان دادن به جنگ‌های بیست‌ساله میان دو قدرت منطقه‌ای آن زمان، ایران صفوی و عثمانی، منعقد شد. بر اساس مفاد این پیمان، ایالت‌های آذربایجان، ارمنستان، داغستان جنوبی و گرجستان شرقی در اختیار دولت صفوی باقی ماندند، در حالی که گرجستان غربی و مناطق عراق کنونی به عثمانی واگذار شدند. این قرارداد حدود ۲۰ سال آرامش و ثبات را بین دو کشور برقرار کرد. شاه تهماسب اول تا پایان عمر خود به مفاد این پیمان پایبند ماند. پیمان آماسیه نخستین معاهده رسمی صلح میان صفویان و عثمانیان به شمار می‌رود و از نظر تاریخی یکی از مهم‌ترین توافقات سیاسی-نظامی در روابط ایران و عثمانی به حساب می‌آید."
#             },
#             {
#                 "answer": "ماند. پیمان آماسیه نخستین معاهده رسمی صلح میان صفویان",
#                 "score": 2.6472196623217314e-05,
#                 "context": "پیمان آماسیه در سال ۱۵۵۵ میلادی میان شاه تهماسب اول از دودمان صفوی و سلطان سلیمان اول از امپراتوری عثمانی به امضا رسید. این پیمان‌نامه در شهر آماسیه واقع در آسیای صغیر به منظور پایان دادن به جنگ‌های بیست‌ساله میان دو قدرت منطقه‌ای آن زمان، ایران صفوی و عثمانی، منعقد شد. بر اساس مفاد این پیمان، ایالت‌های آذربایجان، ارمنستان، داغستان جنوبی و گرجستان شرقی در اختیار دولت صفوی باقی ماندند، در حالی که گرجستان غربی و مناطق عراق کنونی به عثمانی واگذار شدند. این قرارداد حدود ۲۰ سال آرامش و ثبات را بین دو کشور برقرار کرد. شاه تهماسب اول تا پایان عمر خود به مفاد این پیمان پایبند ماند. پیمان آماسیه نخستین معاهده رسمی صلح میان صفویان و عثمانیان به شمار می‌رود و از نظر تاریخی یکی از مهم‌ترین توافقات سیاسی-نظامی در روابط ایران و عثمانی به حساب می‌آید."
#             }
#         ]
#     },
#     {
#         "id": 6,
#         "question": "چند قرار داد نفتی در مربوط به ایران را نام ببر؟",
#         "top_answers": [
#             {
#                 "answer": "یکی مربوط به آزادی گروگان‌های آمریکایی و دیگری مربوط به حل و فصل دعاوی قضایی بین دو کشور از طریق ایجاد نهادی به نام دیوان داوری دعاوی ایران و آمریکا بود. این رویداد در سال ۱۹۸۱ در شهر الجزایر رخ داد. دلایل امضای این قرارداد عبارتند از: تصرف سفارت آمریکا در تهران توسط دانشجویان مسلمان پیرو خط امام،",
#                 "score": 1.728090319375042e-05,
#                 "context": "بیانیه‌های الجزایر قراردادی بین ایران و آمریکا در سال ۱۹۸۱ بود که به گروگان‌گیری سفارت آمریکا در تهران پایان داد. این بیانیه شامل دو اعلامیه دولتی از سوی دولت الجزایر بود که یکی مربوط به آزادی گروگان‌های آمریکایی و دیگری مربوط به حل و فصل دعاوی قضایی بین دو کشور از طریق ایجاد نهادی به نام دیوان داوری دعاوی ایران و آمریکا بود. این رویداد در سال ۱۹۸۱ در شهر الجزایر رخ داد. دلایل امضای این قرارداد عبارتند از: تصرف سفارت آمریکا در تهران توسط دانشجویان مسلمان پیرو خط امام، لزوم آزادی گروگان‌ها و نیاز به ایجاد مکانیسمی برای حل و فصل اختلافات حقوقی بین ایران و آمریکا. طرف‌های درگیر در این واقعه ایالات متحده آمریکا، جمهوری اسلامی ایران و دولت الجزایر بودند. نتیجه امضای بیانیه‌های الجزایر پایان گروگان‌گیری و آزادسازی گروگان‌های آمریکایی بود. تاثیرات این قرارداد شامل پایان دادن به بحران گروگان‌گیری و تلاش برای حل اختلافات بین دو کشور بود، هرچند تحریم‌ها و عدم اجرای کامل مفاد قرارداد باعث محدود شدن اثرات آن شد. اهمیت تاریخی این بیانیه‌ها در کمک به پایان دادن به گروگان‌گیری و ایجاد چارچوبی برای مذاکرات حقوقی میان ایران و آمریکا نهفته است."
#             }
#         ]
#     },
#     {
#         "id": 8,
#         "question": "شیخ عبدالنبی نوری که بود؟",
#         "top_answers": [
#             {
#                 "answer": "در ۱۳۲۷ ق، به دست مشروطه‌خواهان و فرار محمد على شاه، اعتلاء الملك به عضويت محكمه قضاوت عالى درآمد. كار اين محكمه، محاكمۀ مخالفان مشروطه بود كه به حكم آن كسانى چون آيت اللّه شيخ فضل اللّه نورى و ميرهاشم تبريزى (دوه‌چى) به دار آويخته شدند. این واقعه در استان تهران رخ داده است. شهر آن تهران بوده است. مختصات جغرافیایی این رویداد",
#                 "score": 1.591804721101653e-05,
#                 "context": "نصر اللّه خان خلعتبرى، ملقب به اعتلاء الملك، در ۱۲۸۸ ق در تهران به دنيا آمد. پدرش ميرزا شكر اللّه خلعتبرى معروف به نامه‌نگار در وزارت امور خارجه به كارنامه‌نگارى اشتغال داشت. پس از اخذ ديپلم در علوم رياضى از دار الفنون تهران، در ۱۳۰۸ ق به استخدام وزارت امور خارجه درآمد و در اداره محاسبات مشغول به كار شد و در ۱۳۱۶ ق لقب اعتلاء الملك گرفت. پس از فتح تهران، در ۱۳۲۷ ق، به دست مشروطه‌خواهان و فرار محمد على شاه، اعتلاء الملك به عضويت محكمه قضاوت عالى درآمد. كار اين محكمه، محاكمۀ مخالفان مشروطه بود كه به حكم آن كسانى چون آيت اللّه شيخ فضل اللّه نورى و ميرهاشم تبريزى (دوه‌چى) به دار آويخته شدند. این واقعه در استان تهران رخ داده است. شهر آن تهران بوده است. مختصات جغرافیایی این رویداد برابر است با عرض جغرافیایی 35.6892 و طول جغرافیایی 51.3889. نویسنده این متن حسن فراهانی است. این متن از منبع روز شمار تاریخ معاصر ایران، ج ۲، ص ۳۵۸ بدست آمده است. در سال ۱۳۸۵ گرده اوری شده است."
#             }
#         ]
#     },
#     {
#         "id": 9,
#         "question": "چند شاه از سلسله قاجار را نام ببر؟",
#         "top_answers": [
#             {
#                 "answer": "کرد، اما مدت کوتاهی پس از مرگش پسرش‌ پاول یکم که به عنوان جانشین او آمد حمله به ایران را لغو و ارتش روسیه از قلمرو ایران خارج شد. سالهای بعد همچنین آشفته بودند و به عنوان زمان آشفتگی شناخته می‌شد. برقراری مجد حکومت ایران بر گرجستان مدت زیادی طول نکشید، زیرا شاه در سال ۱۷۹۷ در شوشی ترور",
#                 "score": 2.428012521704659e-05,
#                 "context": "نبرد کرتسانیسی نبردی بود که در ۱۷۹۵ میلادی (۱۱۷۴ خورشیدی) پس از مصالحه قره‌باغ و در منطقه کرتسانیسی تفلیس روی داد. این نبرد میزان آقامحمدخان قاجار و ایراکلی دوم، پادشاه کارتلی-کاختی در تفلیس اتفاق افتاد. دلیل آن شورش در قفقاز بود که از دوره زندیه به بعد خود را تحت‌الحمایه روسیه تزاری می‌دانستند و با آن دولت ه
#             }
#         ]
#     },
#     {
#         "id": 11,
#         "question": "سيد ولى اللّه نصر چه مدرک علمی داشت؟",
#         "top_answers": []
#     },
#     {
#         "id": 12,
#         "question": "چند رجال سیاسی عصر قاجار را نام ببرید؟",
#         "top_answers": [
#             {
#                 "answer": "زرتشتیان در مجلس و از رجال سیاسی عصر قاجار و پهلوی فرزند شاهرخ در سال ۱۲۵۳ ش، در كرمان متولد شد. نویسنده این متن حسن فراهانی است. این متن از منبع روز شمار تاریخ معاصر ایران، ج ۱، ص ۲۱۹ بدست آمده است. در سال ۱۳۸۵ گرده اوری",
#                 "score": 0.00017710037354845554,
#                 "context": "ارباب كيخسرو  نماینده زرتشتیان در مجلس و از رجال سیاسی عصر قاجار و پهلوی فرزند شاهرخ در سال ۱۲۵۳ ش، در كرمان متولد شد. نویسنده این متن حسن فراهانی است. این متن از منبع روز شمار تاریخ معاصر ایران، ج ۱، ص ۲۱۹ بدست آمده است. در سال ۱۳۸۵ گرده اوری شده است."
#             },
#             {
#                 "answer": "افشار معروف به جهانشاه خان امير افشار از رجال نظامی و سیاسی عصر قاجار و ملقب به سردار افشار و امير تومان",
#                 "score": 5.419246735982597e-05,
#                 "context": ".محمد حسن خان افشار معروف به جهانشاه خان امير افشار از رجال نظامی و سیاسی عصر قاجار و ملقب به سردار افشار و امير تومان فرزند حسن على خان سردار فاتح در ۱۲۱۷ ش/ ۱۲۵۴ ق در روستاى كرسف زنجان به دنيا آمد. این واقعه در استان زنجان رخ داده است. شهر آن روستای کرسف زنجان بوده است. مختصات جغرافیایی این رویداد برابر است با عرض جغرافیایی 36.6789 و طول جغرافیایی 48.5056. نویسنده این متن حسن فراهانی است. این متن از منبع روز شمار تاریخ معاصر ایران، ج ۲، ص ۱۶۰ بدست آمده است. در سال ۱۳۸۵ گرده اوری شده است"
#             }
#         ]
#     },
#     {
#         "id": 13,
#         "question": "حسن آشتيانى در چه تاریخی فوت کردند و در کجا به خاک سپرده شدند؟",
#         "top_answers": [
#             {
#                 "answer": "واقعه در استان تهران رخ داده است. شهر آن تهران بوده است. مختصات جغرافیایی این رویداد برابر است با عرض جغرافیایی 35.6892 و طول جغرافیایی 51.3889. نویسنده این متن حسن فراهانی است. این متن از منبع روز شمار تاریخ معاصر ایران، ج ۲، ص ۶۴۶ بدست آمده است. در سال ۱۳۸۵ گرده اوری",
#                 "score": 2.8034062779624946e-05,
#                 "context": " ميرزا حسن آشتيانى مستوفى الممالك (سوم) فرزند ميرزا يوسف مستوفى الممالك كه بعدها نام خانوادگى مستوفى گرفت در ۱۲۹۲ ق/ ۱۲۵۰ ش در تهران به دنيا آمد. تحصيلات مقدماتى را نزد معلمين خصوصى فراگرفت و در سن ۶ يا ۷ سالگى پس از اينكه ميرزا يوسف خان، صدراعظم ناصر الدين شاه شد بنا به درخواست وى از شاه لقب و منصب مستوفى الممالك (وزير دارايى آن زمان) به ميرزا حسن رسيد و حاج ميرزا نصر اللّه گرگانى كه
رزا حسن آشتيانى و شيخ فضل اللّه نورى گذراند. در ۱۳۱۱ ق براى تكميل تحصيلات خود به نجف رفت و از محضر ميرزا حبيب اللّه رشتى و ملاعلى نهاوندى و شيخ محمد كاظم خراسانى و سيد محمد كاظم يزدى بهره برد. این واقعه در استان قم رخ داده است. شهر آن قم بوده است. مختصات جغرافیایی این رویداد برابر است با عرض جغرافیایی 34.64 و طول جغرافیایی 50.8764. نویسنده این متن حسن فراهانی است. این متن از منبع روز شمار تاریخ معاصر ایران، ج ۲، ص ۳۶۴ بدست آمده است. در سال ۱۳۸۵ گرده اوری شده است."
#             },
#             {
#                 "answer": "در ۱۳۰۳ ق به حج مشرف شد و در بازگشت مدتى در سامرا در محضر درس آيت اللّه ميرزاى شيرازى حضور يافت. در ۱۳۰۶ ق به تهران آمد و به فراگيرى علوم دينى ادامه داد. وى اينك در حوزه علوم عقلى و عرفان شاگرد ميرزا ابو الحسن جلوه و شيخ على مدرس يزدى و ميرزا محمود قمى بود و درس فقه و اصول را نزد ميرزا حسن آشتيانى",
#                 "score": 1.301823249377776e-05,
#                 "context": "حاج آقا حسين قمى فرزند سيد محمود به سال ۱۲۸۲ ق در قم به دنيا آمد. وى در خانواده سادات طباطبايى حسينى تربيت يافت و تحصيلات مقدماتى را در زادگاه خود و سطح را در تهران گذراند. در ۱۳۰۳ ق به حج مشرف شد و در بازگشت مدتى در سامرا در محضر درس آيت اللّه ميرزاى شيرازى حضور يافت. در ۱۳۰۶ ق به تهران آمد و به فراگيرى علوم دينى ادامه داد. وى اينك در حوزه علوم عقلى و عرفان شاگرد ميرزا ابو الحسن جلوه و شيخ على مدرس يزدى و ميرزا محمود قمى بود و درس فقه و اصول را نزد ميرزا حسن آشتيانى و شيخ فضل اللّه نورى گذراند. در ۱۳۱۱ ق براى تكميل تحصيلات خود به نجف رفت و از محضر ميرزا حبيب اللّه رشتى و ملاعلى نهاوندى و شيخ محمد كاظم خراسانى و سيد محمد كاظم يزدى بهره برد. این واقعه در استان قم رخ داده است. شهر آن قم بوده است. مختصات جغرافیایی این رویداد برابر است با عرض جغرافیایی 34.64 و طول جغرافیایی 50.8764. نویسنده این متن حسن فراهانی است. این متن از منبع روز شمار تاریخ معاصر ایران، ج ۲، ص ۳۶۴ بدست آمده است. در سال ۱۳۸۵ گرده اوری شده است."
#             }
#         ]
#     },
#     {
#         "id": 17,
#         "question": "عهدنامه ترکمانچای و پیمان سنت پترزبورگ چه تأثیرات مشترکی بر از دست رفتن سرزمین‌های ایران به نفع روسیه داشتند؟",
#         "top_answers": [
#             {
#                 "answer": "شدند. طرف‌های درگیر در این معاهده ایران به رهبری فتحعلی‌شاه و روسیه به نمایندگی ایوان پاسکویچ بودند. همچنین نقش میرزا ابوالحسن خان شیرازی و ولی‌الله‌یار خان آصف‌الدوله نیز در مذاکرات قابل توجه است. نتیجه این قرارداد، محدود شدن حاکمیت ایران بر دریای خزر و از دست دادن بخش‌های مهمی از قلمرو کشور بود. اهمیت تاریخی عهدنامه ترکمانچای در پایان دادن به جنگ‌های ایران و روسیه در دوره قاجار",
#             }
#         ]
#     },
#     {
#         "id": 18,
#         "question": "کنوانسیون وین برای محافظت از لایه ازون و پیمان مونترال چه اهداف مشترکی در حفاظت از محیط زیست داشتند؟",
#         "top_answers": [
#             {
#                 "answer": "در این پیمان شامل پیمان مونترال و کنوانسیون وین برای محافظت از لایه ازون بودند. نتیجه این پیمان، کاهش قابل توجه سوراخ ازون در قطب جنوب و بهبود وضعیت لایه ازون تا دهه ۱۹۸۰ بود. همچنین، این پیمان به عنوان موفق‌ترین توافق بین‌المللی در زمینه حفاظت از محیط زیست شناخته شده است و نمونه‌ای از همکاری‌های بین‌المللی موثر محسوب می‌شود. اهمیت تاریخی آن در این است که پیمان مونترال",
#                 "score": 3.223184103262611e-05,
#                 "context": "پیمان مونترال در سال ۱۹۸۷ امضا شد و پس از نخستین جلسه در هلسینکی در مه ۱۹۸۹، در تاریخ ۱۶ سپتامبر ۱۹۸۹ به اجرا درآمد. این پیمان با هدف محافظت از لایه ازون و کاهش تولید مواد تخریب‌کننده آن به تصویب رسید. مکان وقوع این رویداد شهر مونترال بود. طرف‌های درگیر در این پیمان شامل پیمان مونترال و کنوانسیون وین برای محافظت از لایه ازون بودند. نتیجه این پیمان، کاهش قابل توجه سوراخ ازون در قطب جنوب و بهبود وضعیت لایه ازون تا دهه ۱۹۸۰ بود. همچنین، این پیمان به عنوان موفق‌ترین توافق بین‌المللی در زمینه حفاظت از محیط زیست شناخته شده است و نمونه‌ای از همکاری‌های بین‌المللی موثر محسوب می‌شود. اهمیت تاریخی آن در این است که پیمان مونترال نخستین معاهده جهانی تصویب شده در تاریخ سازمان ملل متحد است و فرایند سیاست‌گزاری جهانی را تحت تأثیر قرار داده است."
#             },
#             {
#                 "answer": "هدف محافظت از لایه ازون و کاهش تولید مواد تخریب‌کننده آن به تصویب رسید. مکان وقوع این رویداد شهر مونترال بود. طرف‌های درگیر در این پیمان شامل پیمان مونترال",
#                 "score": 3.221622318960726e-05,
#                 "context": "پیمان مونترال در سال ۱۹۸۷ امضا شد و پس از نخستین جلسه در هلسینکی در مه ۱۹۸۹، در تاریخ ۱۶ سپتامبر ۱۹۸۹ به اجرا درآمد. این پیمان با هدف محافظت از لایه ازون و کاهش تولید مواد تخریب‌کننده آن به تصویب رسید. مکان وقوع این رویداد شهر مونترال بود. طرف‌های درگیر در این پیمان شامل پیمان مونترال و کنوانسیون وین برای محافظت از لایه ازون بودند. نتیجه این پیمان، کاهش قابل توجه سوراخ ازون در قطب جنوب و بهبود وضعیت لایه ازون تا دهه ۱۹۸۰ بود. همچنین، این پیمان به عنوان موفق‌ترین توافق بین‌المللی در زمینه حفاظت از محیط زیست شناخته شده است و نمونه‌ای از همکاری‌های بین‌المللی موثر محسوب می‌شود. اهمیت تاریخی آن در این است که پیمان مونترال نخستین معاهده جهانی تصویب شده در تاریخ سازمان ملل متحد است و فرایند سیاست‌گزاری جهانی را تحت تأثیر قرار داده است."
#             },
#             {
#                 "answer": "در زمینه حفاظت از محیط زیست شناخته شده است و نمونه‌ای از همکاری‌های بین‌المللی موثر محسوب می‌شود. اهمیت تاریخی آن در این است که پیمان مونترال",
#                 "score": 3.2194591767620295e-05,
#                 "context": "پیمان مونترال در سال ۱۹۸۷ امضا شد و پس از نخستین جلسه در هلسینکی در مه ۱۹۸۹، در تاریخ ۱۶ سپتامبر ۱۹۸۹ به اجرا درآمد. این پیمان با هدف محافظت از لایه ازون و کاهش تولید مواد تخریب‌کننده آن به تصویب رسید. مکان وقوع این رویداد شهر مونترال بود. طرف‌های درگیر در این پیمان شامل پیمان مونترال و کنوانسیون وین برای محافظت از لایه ازون بودند. نتیجه این پیمان، کاهش قابل توجه سوراخ ازون در قطب جنوب و بهبود وضعیت لایه ازون تا دهه ۱۹۸۰ بود. همچنین، این پیمان به عنوان موفق‌ترین توافق بین‌المللی در زمینه حفاظت از محیط زیست شناخته شده است و نمونه‌ای از همکاری‌های بین‌المللی موثر محسوب می‌شود. اهمیت تاریخی آن در این است که پیمان مونترال نخستین معاهده جهانی تصویب شده در تاریخ سازمان ملل متحد است و فرایند سیاست‌گزاری جهانی را تحت تأثیر قرار داده است."
#             }
#         ]
#     },
#     {
#         "id": 19,
#         "question": "عبدالصمد میرزا عزالدوله چه نقشی در دربار قاجار داشت؟",
#         "top_answers": [
#             {
#                 "answer": "رضا شاه پس از اطلاع از اين ماجرا به ديبا دستور داد مبلغ مزبور را به وراث وى برگرداند و متعاقب همين از دربار اخراج و زندانى شد. این واقعه در استان کرمانشاه",
#                 "score": 3.083498086198233e-05,
#                 "context": "مجلل الدوله دولتشاهى از اعيان و شاهزادگان قاجار و فرزند سلطان ابراهيم ميرزاى مشكوه الدوله فرزند محمد على ميرزا فرزند فتحعليشاه قاجار و نوادۀ دخترى پاشا خان امين الملك بود. وى به سال ۱۲۵۶ ش در كرمانشاه به دنيا آمد. تحصيلاتش را در حدود سطح در موطن خويش انجام داد و براى ادامه تحصيل به فرانسه رفت. پس از بازگشت به ايران نايب الحكومه چند شهر شد و چندى نيز در مناطق مختلف حكومت نمود. در سال ۱۳۰۲ ش رضا خان سردار سپه با دختر وى عصمت الملوك دولتشاهى ازدواج كرد و به همين علت وى از قاجار روى‌گردان شد و در زمرۀ طرفداران رضا خان قرار گرفت. پس از انقراض سلسله قاجار و استقرار رضا خان در سلطنت، مجلل الدوله دولتشاهى در ۲۹ آذر ۱۳۰۴ به رياست تشريفات داخلى دربار پهلوى تعيين گرديد و در جرگۀ درباريان قرار گرفت. وى در ۲ آبان ۱۳۱۱ به علت سكتۀ قلبى فوت كرد. وى از قماربازان معروف بود و بيشتر وقت خود را صرف آن مى‌كرد. مخبر السلطنه هدايت علت مرگ مجلل الدوله را به علت باخت مبلغ ۲۵ هزار تومان در قمار دانسته است. ظاهرا شبى كه وى سكته كرد مبلغ ۲۵ هزار تومان به وكيل الملك ديبا رئيس حسابدارى دربار باخته بود. رضا شاه پس از اطلاع از اين ماجرا به ديبا دستور داد مبلغ مزبور را به وراث وى برگرداند و متعاقب همين از دربار اخراج و زندانى شد. این واقعه در استان کرمانشاه رخ داده است. شهر آن کرمانشاه بوده است. مختصات جغرافیایی این رویداد برابر است با عرض جغرافیایی 34.3325 و طول جغرافیایی 47.0933. نویسنده این متن حسن فراهانی است. این متن از منبع روز شمار تاریخ معاصر ایران، ج ۲، ص ۳۱۴ بدست آمده است. در سال ۱۳۸۵ گرده اوری شده است."
#             }
#         ]
#     },
#     {
#         "id": 20,
#         "question": "چه کسی به‌عنوان سفیر روسیه در مذاکرات عهدنامه رشت حضور داشت؟",
#         "top_answers": [
#             {
#                 "answer": "رسید. یکی از دلایل مهم امضای این عهدنامه نامه‌ای بود که ملکه آنا در ماه اکتبر ۱۷۳۰ به شاه تهماسب دوم نوشت و در آن شرایط تخلیه نیروهای روس از گیلان را یادآور شد. بارون",
#                 "score": 2.2164593246998265e-05,
#                 "context": "عهدنامه رشت قراردادی است که بین ایران و امپراتوری روسیه در سال ۱۷۳۲ میلادی منعقد شد. این قرارداد در شهر رشت به امضا رسید و در ۱۲ بهمن ۱۱۱۰ خورشیدی (برابر با ۲۱ ژانویه ۱۷۳۲ میلادی) به ثبت رسید. یکی از دلایل مهم امضای این عهدنامه نامه‌ای بود که ملکه آنا در ماه اکتبر ۱۷۳۰ به شاه تهماسب دوم نوشت و در آن شرایط تخلیه نیروهای روس از گیلان را یادآور شد. بارون شافیروف سفیر روسیه در رشت حضور داشت. بر اساس این قرارداد، روسیه متعهد شد ظرف پنج ماه تمامی نواحی متصرفی خود را در ایران تخلیه کند. طرفین درگیر این قرارداد ایران و امپراتوری روسیه بودند. نتیجه امضای عهدنامه، تخلیه نیروهای روس از گیلان بود و تأثیرات آن شامل آزادی تجارت بین ایران و روسیه، ایجاد نمایندگی سیاسی در کشورهای دیگر و بازگرداندن شهرهایی مانند بندر، گنجه و دیگر مناطق به ایران بود. اهمیت تاریخی عهدنامه رشت در پایان اشغالگری روسیه در منطقه و بازگشت کنترل این مناطق به ایران نهفته است."
#             },
#             {
#                 "answer": "بود. اهمیت تاریخی عهدنامه رشت در پایان اشغالگری روسیه در منطقه و بازگشت کنترل این مناطق به ایران نهفته است.",
#                 "score": 2.2056177840568125e-05,
#                 "context": "عهدنامه رشت قراردادی است که بین ایران و امپراتوری روسیه در سال ۱۷۳۲ میلادی منعقد شد. این قرارداد در شهر رشت به امضا رسید و در ۱۲ بهمن ۱۱۱۰ خورشیدی (برابر با ۲۱ ژانویه ۱۷۳۲ میلادی) به ثبت رسید. یکی از دلایل مهم امضای این عهدنامه نامه‌ای بود که ملکه آنا در ماه اکتبر ۱۷۳۰ به شاه تهماسب دوم نوشت و در آن شرایط تخلیه نیروهای روس از گیلان را یادآور شد. بارون شافیروف سفیر روسیه در رشت حضور داشت. بر اساس این قرارداد، روسیه متعهد شد ظرف پنج ماه تمامی نواحی متصرفی خود را در ایران تخلیه کند. طرفین درگیر این قرارداد ایران و امپراتوری روسیه بودند. نتیجه امضای عهدنامه، تخلیه نیروهای روس از گیلان بود و تأثیرات آن شامل آزادی تجارت بین ایران و روسیه، ایجاد نمایندگی سیاسی در کشورهای دیگر و بازگرداندن شهرهایی مانند بندر، گنجه و دیگر مناطق به ایران بود. اهمیت تاریخی عهدنامه رشت در پایان اشغالگری روسیه در منطقه و بازگشت کنترل این مناطق به ایران نهفته است."
#             },
#             {
#                 "answer": "رسید. یکی از دلایل مهم امضای این عهدنامه نامه‌ای بود که ملکه آنا",
#                 "score": 2.1987281797919422e-05,
#                 "context": "عهدنامه رشت قراردادی است که بین ایران و امپراتوری روسیه در سال ۱۷۳۲ میلادی منعقد شد. این قرارداد در شهر رشت به امضا رسید و در ۱۲ بهمن ۱۱۱۰ خورشیدی (برابر با ۲۱ ژانویه ۱۷۳۲ میلادی) به ثبت رسید. یکی از دلایل مهم امضای این عهدنامه نامه‌ای بود که ملکه آنا در ماه اکتبر ۱۷۳۰ به شاه تهماسب دوم نوشت و در آن شرایط تخلیه نیروهای روس از گیلان را یادآور شد. بارون شافیروف سفیر روسیه در رشت حضور داشت. بر اساس این قرارداد، روسیه متعهد شد ظرف پنج ماه تمامی نواحی متصرفی خود را در ایران تخلیه کند. طرفین درگیر این قرارداد ایران و امپراتوری روسیه بودند. نتیجه امضای عهدنامه، تخلیه نیروهای روس از گیلان بود و تأثیرات آن شامل آزادی تجارت بین ایران و روسیه، ایجاد نمایندگی سیاسی در کشورهای دیگر و بازگرداندن شهرهایی مانند بندر، گنجه و دیگر مناطق به ایران بود. اهمیت تاریخی عهدنامه رشت در پایان اشغالگری روسیه در منطقه و بازگشت کنترل این مناطق به ایران نهفته است."
#             }
#         ]
#     },
#     {
#         "id": 21,
#         "question": "چرا فرورتیش علی‌رغم دست‌نشانده بودن توسط آشوریان، تصمیم گرفت به آن‌ها اعلان جنگ دهد؟",
#         "top_answers": [
#             {
#                 "answer": "کند. در جریان یک کشمکش داخلی در آشور، فرورتیش فرصت را برای حملهٔ دوباره به آشور مناسب دید و بدین ترتیب در سال ۶۵۳ پیش از میلاد مجداً به آشور یورش برد ولی کشته شد. بدین ترتیب ۲۲ سال حکومت وی بر مادها این",
#                 "score": 1.2394827535899822e-05,
# ...
#             }
#         ]
#     },
#     {
#         "id": 48,
#         "question": "نتیجه نبرد پاسارگاد و اکباتان در سال ۵۵۱ قبل از میلاد چه بود و چه تاثیری بر نیروهای ماد و پارس داشت؟",
#         "top_answers": [
#             {
#                 "answer": "در سال 551 شروع شده است. نتیجه این رویداد: پیروزی استراتژیک مادها و عقب‌نشینی پارس‌ها به جنوب برای آمادگی در نبرد سوم",
#                 "score": 0.00017856938939075917,
#                 "context": "این رویداد در سال 551 شروع شده است. نتیجه این رویداد: پیروزی استراتژیک مادها و عقب‌نشینی پارس‌ها به جنوب برای آمادگی در نبرد سوم در تاریخ 551 قبل از میلاد، در این نبرد، نیروهای ماد و پارس در مرزهای بین این دو امپراتوری درگیر شدند و نتیجه آن پیروزی استراتژیک مادها و عقب‌نشینی پارس‌ها بود."
#             },
#             {
#                 "answer": "پارس‌ها به جنوب برای آمادگی در نبرد سوم",
#                 "score": 0.0001781409082468599,
#                 "context": "این رویداد در سال 551 شروع شده است. نتیجه این رویداد: پیروزی استراتژیک مادها و عقب‌نشینی پارس‌ها به جنوب برای آمادگی در نبرد سوم در تاریخ 551 قبل از میلاد، در این نبرد، نیروهای ماد و پارس در مرزهای بین این دو امپراتوری درگیر شدند و نتیجه آن پیروزی استراتژیک مادها و عقب‌نشینی پارس‌ها بود."
#             }
#         ]
#     },
#     {
#         "id": 49,
#         "question": "نبرد سالامیس در چه مکانی اتفاق افتاد و نتیجه آن چه بود؟",
#         "top_answers": [
#             {
#                 "answer": "در سال 480 شروع شده است. و در سال 480 به اتمام رسید. نتیجه این رویداد:",
#                 "score": 0.00011332271242281422,
#                 "context": "این رویداد در سال 480 شروع شده است. و در سال 480 به اتمام رسید. نتیجه این رویداد: شکست ناوگان ایران و پیروزی یونانیان در نبرد سالامیس و پایان تهاجم ایران به یونان در آن سال این رویداد در شهر سالامیس اتفاق افتاده است. در تاریخ 480-09-26، نیروهای ایرانی و یونانی در تنگه سالامیس درگیر شدند. در تاریخ 480-09-27، نبرد با شکست ناوگان ایرانی و پیروزی یونانیان خاتمه یافت."
#             },
#             {
#                 "answer": "در سال 480 شروع شده است. و در سال 480 به اتمام رسید. نتیجه این رویداد: شکست ناوگان ایران و پیروزی یونانیان در نبرد سالامیس و پایان تهاجم ایران",
#                 "score": 0.0001131416138377972,
#                 "context": "این رویداد در سال 480 شروع شده است. و در سال 480 به اتمام رسید. نتیجه این رویداد: شکست ناوگان ایران و پیروزی یونانیان در نبرد سالامیس و پایان تهاجم ایران به یونان در آن سال این رویداد در شهر سالامیس اتفاق افتاده است. در تاریخ 480-09-26، نیروهای ایرانی و یونانی در تنگه سالامیس درگیر شدند. در تاریخ 480-09-27، نبرد با شکست ناوگان ایرانی و پیروزی یونانیان خاتمه یافت."
#             }
#         ]
#     },
#     {
#         "id": 50,
#         "question": "در جنگ زنجیر چه کسی فرماندهی اعراب مسلمان را بر عهده داشت؟",
#         "top_answers": [
#             {
#                 "answer": "کینه و نفرت داشتند. از سوی دیگر حقیقت را نویسندگان شکل دیگری می‌بینند. کلود کائن می‌نویسد که تحت تأثیر جنبش‌های ملی گرایانه دوران مدرن، گرایش به سمت نمایش ایرانیان و اعراب به عنوان دو گروه دشمن رفته است، درحالی‌که این دیدگاه با حقایق تاریخی سازگار نیست. چیز رابینسون نیز خشونت‌های نظام مند دوران فتوحات برابر غیرمسلمانان تا پیش از مروانیان",
#                 "score": 4.0559767512604594e-05,
#                 "context": "حمله اعراب به ایران که بخشی از فتوحات مسلمانان به شمار می آید. به مجموعه یورش‌ها به شاهنشاهی ساسانی در قرن هفتم میلادی اشاره دارد که از سال ۶۳۳ میلادی در دوران خلافت ابوبکر آغاز شد، در دوران عمر به اوج خود رسید و در زمان عثمان به فروپاشی کامل پادشاهی ساسانی در سال ۶۵۱ میلادی (مطابق با سال ۳۰ هجری ق
روی اعراب ایستادگی‌های محلی بود که در برخی موارد شدید بودند. فتوحات اعراب به سوی شرق ادامه یافت. در چند سال ولایت‌های دیگر ایران شامل اصفهان، ری، فارس، آذربایجان، ارمنستان ایران، سیستان و خراسان نیز فرو ریختند. با این حال طبرستان و نیز گیلان تا یکی دو سده زیر فرمان اعراب در نیامدند و افرادی از اشراف ایران در آنجا فرمانروایی می‌کردند، چنان‌که احمد کسروی در بهار نوشته است: «اوایل قرن سوم که دامنهٔ فتوحات اسلامی در آسیا تا حدود چین و در آفریقا تا سواحل بحر اطلس و در اروپا تا وراء جبل آلپ امتداد یافته بود و در پایتخت‌های اسپانیا و پرتغال به جای ناقوس صدای اذان مسلمین به اطراف طنین می‌انداخت، در قلعه جبال سوادکوه آتشکده‌های دین زرتشت دایر و مشتعل بود و اسپهبدان هنوز کیش نیاکان خود را از دست نداده بودند.» اعراب پس از اشغال هر شهری قراردادی با سران آن شهر می‌بستند که در آن میزان مالیاتی (جَزیه) که قرار است که از شهر اخذ شود را مشخص می‌کرد. روال کلی این بود که شهرها پس از عقد قرارداد صلح، شهرها قیام می‌کردند. قیام‌ها مخصوصاً تا ۶۵۱ میلادی که یزدگرد زنده بود، بیشتر رایج بود و مقاومت‌های محلی قوی و مکرر بود. در برخی موارد مخالفان نیروی بزرگی نیز فراهم کرده بودند. مورخان در مورد انگیزه قیام‌ها نظرات مختلفی دارند. گذشته‌نگاران دلایل بسیاری را در مورد انگیزه و علت آغاز یورش‌های اعراب به ایران گفته‌اند: دورنمای کسب ثروت و زمین، گرسنگی و فقر، تلاش برای گسترش اسلام، تلاش برای رها کردن اعراب بین‌النهرین از سلطه ساسانیان، عرب گرایی، تغییرات آب و هوایی، گسترش شبکه تجاری و غیره. همچنین گذشته‌نگاران دلایل گوناگونی را برای فروپاشی ساسانیان بیان کرده‌اند: درگیری مذهبی و گروهی، نبود پشتیبانی مردمی، درگیری میزان اشراف، ناپایداری سیاسی، و هزینه درگیری‌های طولانی و ناموفق اخیر با امپراتوری روم شرقی، اپیدمی طاعون، آشفتگی مربوط به جانشینی تخت پادشاهی، دین اسلام، اختلافات میزان گروه‌های گوناگون جامعه و نبود هماهنگی میزان آنها، باور ایرانیان به سرنوشت و پذیرش شکست، وجود پیروان فرقه‌های غیر آیین مزدیسنا (زرتشتی) و مسیحیان که در پشتیبانی از معابد آتش و خانواده ساسانی رخنه ایجاد می‌کردند و عوامل دیگر. تا هنگام قتل عثمان، اشغال کردن ایران، کامل شده بود و پادگان‌های اعراب در چند منطقه جهت اطمینان از اخذ مالیات برقرار شده بود. از زمان معاویه به بعد برنامه اسکان دائمی برخی اعراب در ایران اجرا شد. در زمان میزان اعراب از آمودریا فراتر رفته و وارد کوه‌های افغانستان شدند. اعراب معمولاً در امور داخلی مردمان محلی که مالیات خود را می‌پرداختند دخالت نمی‌کردند. در قرون اول اسلامی، سران محلی مسئولیت اداره محلات و شهرها را بر عهده داشتند. پس از فتح یک ناحیه، اعراب در پادگان‌های که ساکن می‌شد ...
#             }
#         ]
#     }
# ]
